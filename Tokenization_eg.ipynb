# %%
import nltk

# %%
corpus = """ Hello welcome, to Krish's NLP tutorial.
please do watch the entire course ! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
#  Hello welcome, to Krish's NLP tutorial.
# please do watch the entire course ! to become expert in NLP.

# %% [raw]
# # Converting corpus ==> documents

# %%
from nltk.tokenize import sent_tokenize
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello welcome, to Krish's NLP tutorial.
# please do watch the entire course !
# to become expert in NLP.

# %% [raw]
# # Converting documents to words
# # paragraph --> word
# # sentence --> word

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Krish',
#  "'s",
#  'NLP',
#  'tutorial',
#  '.',
#  'please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'to', 'Krish', "'s", 'NLP', 'tutorial', '.']
# ['please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Krish',
#  "'",
#  's',
#  'NLP',
#  'tutorial',
#  '.',
#  'please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokens = TreebankWordTokenizer()
tokens.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Krish',
#  "'s",
#  'NLP',
#  'tutorial.',
#  'please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
